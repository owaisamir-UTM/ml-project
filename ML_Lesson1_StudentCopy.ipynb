# %% [markdown]
# <a href="https://colab.research.google.com/github/RuiYan2022/UTM-2026-Winter-/blob/main/ML_Lesson1_StudentCopy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning Workshop — Lesson 1 (No AI)**
#
# **Build Your First Machine Learning Model**
#
# *Goal*: Understand the basic ML workflow using sklearn.
#
# *Workflow:*
#
# Data → Train/Test Split → Train Model → Predict → Evaluate → Improve

# %% [markdown]
# **1. Load Dataset**
#
# We use the sklearn Breast Cancer dataset so we can focus on ML concepts.

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

data = load_breast_cancer()

X = pd.DataFrame(data.data, columns=data.feature_names)
y = pd.Series(data.target)

# %% [markdown]
# **2. Train/Test Split**
#
# Why split data? To test on unseen data.

# %% [markdown]
# **3. Train First Model**
#
# Decision Tree classifier

# %% [markdown]
# **4. Make Predictions**

# %% [markdown]
# **5. Accuracy**

# %% [markdown]
# **6. Confusion Matrix**

# %% [markdown]
# **7. Visualize the Tree**

# %% [markdown]
# **8. Overfitting Experiment**

# %% [markdown]
# **9. Model Comparison**
